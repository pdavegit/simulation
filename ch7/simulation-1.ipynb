# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import math
x = np.arange(0, 10, 0.1)
y = 1 - np.exp(-x)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_title("exp")
ax.set_xlabel("x")
ax.set_ylabel("F")
# Out:
# Text(0, 0.5, 'F')

# %%
u = np.random.random(10000)
x = -np.log(1 - u)

# %%
plt.hist(u, bins=20)
plt.hist(x, bins=20)
# Out:
# (array([4.051e+03, 2.309e+03, 1.485e+03, 9.080e+02, 4.780e+02, 2.950e+02,
#         1.850e+02, 1.080e+02, 7.400e+01, 2.800e+01, 3.300e+01, 2.100e+01,
#         1.300e+01, 5.000e+00, 2.000e+00, 2.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00]),
#  array([6.15657221e-05, 5.17520880e-01, 1.03498019e+00, 1.55243951e+00,
#         2.06989882e+00, 2.58735814e+00, 3.10481745e+00, 3.62227677e+00,
#         4.13973608e+00, 4.65719540e+00, 5.17465471e+00, 5.69211403e+00,
#         6.20957334e+00, 6.72703265e+00, 7.24449197e+00, 7.76195128e+00,
#         8.27941060e+00, 8.79686991e+00, 9.31432923e+00, 9.83178854e+00,
#         1.03492479e+01]),
#  <a list of 20 Patch objects>)

# %%
x = np.arange(0, 1, 0.01)
f = 20*x*(1-x)**3
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x,f)

# %%
def g(x):
    return 1
def f(x):
    return 20*x*(1-x)*(1-x)*(1-x)
counter = 0
def rejection():
    while True:
        global counter
        counter += 1
        y = random.random()
        u = random.random()
        c = 135/64
        c = 3
        if u <= f(y) / (c * g(y)):
            return y

# %%
counter = 0
n = 10000
X = [rejection() for x in range(n)]
print(counter/n - 135.0/64)
# Out:
# 0.8411249999999999

# %%
counter
# Out:
# 2133

# %%
plt.hist(X, bins=20)
# Out:
# (array([195., 514., 753., 854., 948., 996., 964., 879., 795., 749., 588.,
#         470., 406., 321., 207., 183., 103.,  49.,  16.,  10.]),
#  array([0.00130557, 0.04714314, 0.09298072, 0.13881829, 0.18465586,
#         0.23049344, 0.27633101, 0.32216858, 0.36800616, 0.41384373,
#         0.4596813 , 0.50551888, 0.55135645, 0.59719402, 0.6430316 ,
#         0.68886917, 0.73470674, 0.78054432, 0.82638189, 0.87221946,
#         0.91805704]),
#  <a list of 20 Patch objects>)

# %%
np.random.exponential()
# Out:
# 1.7629216930619676

# %%
pi = 4*math.atan(1)
e = math.exp(1)
c = math.sqrt(2.0*e/pi)
print(pi, e, c)
# Out:
# 3.141592653589793 2.718281828459045 1.315489246958914

# %%
def rejnormal(c):
    while True:
        global counter
        counter += 1
        y = np.random.exponential()
        u = random.random()
        if u <= f(y) / (c * g(y)):
            return y

# %%
X = [rejnormal(c) for i in range(10000)]

# %%
plt.hist(X, bins=20)
# Out:
# (array([371., 911., 971., 937., 887., 861., 808., 797., 753., 715., 610.,
#         445., 351., 264., 156.,  83.,  51.,  23.,   5.,   1.]),
#  array([0.00129851, 0.04974377, 0.09818903, 0.1466343 , 0.19507956,
#         0.24352483, 0.29197009, 0.34041535, 0.38886062, 0.43730588,
#         0.48575115, 0.53419641, 0.58264167, 0.63108694, 0.6795322 ,
#         0.72797746, 0.77642273, 0.82486799, 0.87331326, 0.92175852,
#         0.97020378]),
#  <a list of 20 Patch objects>)
